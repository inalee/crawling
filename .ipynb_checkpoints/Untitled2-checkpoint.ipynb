# %%
import os
import sys
import urllib.request
client_id = "RAZSrGuJmbZcN1ATKYX2"
client_secret = "JAM47GNGbd"
encText = urllib.parse.quote("sk가스충전소")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sat, 25 Apr 2020 22:05:07 +0900",
# "total": 1138,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "서산<b>SK가스충전소</b> 정보",
# "link": "http://cafe.naver.com/joycamping/303170",
# "description": "몽산포 장박중이라 지난주 일요일 집에가는길에 <b>SK가스충전소</b>갔더니.. 안된다고 막 손을 흔드시네요! 으잉?? 까페에서 된다구본것 같았는데... ㅜㅜ 어제 들어오며 혹시나해서 다시 전화해봤습니다. 일요일은... ",
# "cafename": "\"달구지 캠핑\"",
# "cafeurl": "https://cafe.naver.com/joycamping"
#
# },
# {
# "title": "lpg 충전 어디서 하세요? <b>sk가스 충전소</b>? sk에너지 충전소?",
# "link": "http://cafe.naver.com/m300club/1661424",
# "description": "sk lpg<b>충전소</b> 보면 <b>sk가스</b>랑 sk에너지랑 두가지 회사의 <b>충전소</b>가 있는데요 lpg가스팍 회원님들은 체감상 어떤 회사의 가스가 좀더 토크감이나 연비등 여러가지로 어디가좀 더 나은것 같으셨나요? 굼금합니다 더... ",
# "cafename": "쉐보레 더 뉴 스파크 동호회 [스파크 ...",
# "cafeurl": "https://cafe.naver.com/m300club"
#
# },
# {
# "title": "현금만 달라는 가스 <b>충전소</b>..",
# "link": "http://cafe.naver.com/joycamping/462257",
# "description": "하남에 있는 sk ** 가스<b>충전소</b>를 갔습니다.10kg 충전 하고 카드를 내니 카드는 안받는 답니다.개인소비자 거래도 안하는데 해주는 거라며 카드는 안받겠다 하데요.현금주고 가스 충전 했는데 내 돈주고 가스 산건데 왠지... ",
# "cafename": "\"달구지 캠핑\"",
# "cafeurl": "https://cafe.naver.com/joycamping"
#
# },
# {
# "title": "<b>sk가스충전소</b>7000원할인권(1500원)",
# "link": "http://cafe.naver.com/joonggonara/537783135",
# "description": "개인거래(판매), 판매중, 가격 2,000원, 직접거래, <b>sk가스충전소</b>7000원할인권(1500원), 25000원 이상 충전시 7000원 할인입니다",
# "cafename": "중고나라",
# "cafeurl": "https://cafe.naver.com/joonggonara"
#
# },
# {
# "title": "첫마을 5 6 7ㅡ희소식입니다ㅡ가람동 유보지 끝ㅡSK주유소 및 커피샵 오픈 준비중 인것같네요ㅡ<b>SK가스충전소</b>...",
# "link": "http://cafe.naver.com/1sejongcity/839905",
# "description": ".그앞 금강뷰 2층건물 3층루프탑 전경 가람동 끝 금강뷰 보이는 곳에 SK주유소 및 커피샾 또는 버거 ???오픈준비중 주로 SK주유소는 버거킹 붙음인데 여긴 2층건물에 3층 루프탑 까지 보이네요 그앞은 금강뷰... ",
# "cafename": "세종시닷컴",
# "cafeurl": "https://cafe.naver.com/1sejongcity"
#
# },
# {
# "title": "장림<b>sk가스 충전소</b> 일요일도 충전 될까요?",
# "link": "http://cafe.naver.com/busancampingclub/39630",
# "description": "장림 가스 <b>충전소</b> 일요일도 충전 될까요? 전화가 안되네요 ㅜㅜ 충전하러 갈 시간이 안나요 ㅜㅜ",
# "cafename": "부산캠핑클럽(초보캠핑)",
# "cafeurl": "https://cafe.naver.com/busancampingclub"
#
# },
# {
# "title": "<b>SK가스</b>, 11월 국내 LPG가격 kg당 50원 인상",
# "link": "http://cafe.naver.com/clubcarensrp/52380",
# "description": "이로 인해 <b>SK가스</b>와 거래하는 산업체, <b>충전소</b> 등 주요 거래처는 가정 및 상업용 프로판의 경우 종전 kg당 796.36원이던 것이 846.36원으로, LPG벌크로리 등을 통해 공급하는 산업체용은 802.96원에서 852.96원으로 각각... ",
# "cafename": "올뉴카렌스 더뉴카렌스 최강동호회",
# "cafeurl": "https://cafe.naver.com/clubcarensrp"
#
# },
# {
# "title": "(완료)제주도 이호동 <b>sk가스충전소</b> lpg 5천원충전권-나눔",
# "link": "http://cafe.naver.com/joonggonara/283677976",
# "description": "개인거래(판매), 판매중, 가격 1원, 직접거래, 제주도 이호동 <b>sk가스충전소</b> lpg, 중고나라 공식 앱 다운받기 편한 택배 / 퀵 신청하기 판 매 양 식 아이디 이메일싸이,블로그,타카페,타사이트 링크시 삭제 및... ",
# "cafename": "중고나라",
# "cafeurl": "https://cafe.naver.com/joonggonara"
#
# },
# {
# "title": "2020년 3월 LPG 공급단가 가격",
# "link": "http://cafe.naver.com/jmeat/372713",
# "description": "수입사<b>SK가스</b> 959.36원/kg(전월동결), E1 960.80원/kg(전월동결) 부피환산(서울, 경기 기준)저압(2.8kPa) <b>SK가스</b> 1,994.51원/m3, E1 1997.51원/m3준저압(25kPa) <b>SK가스</b> 2,411.76원/m3, E1 2,415.38원/m3 <b>충전소</b>전국평... ",
# "cafename": "고창모[고기집창업]",
# "cafeurl": "https://cafe.naver.com/jmeat"
#
# },
# {
# "title": "상동<b>sk 가스 충전소</b> 에서 아르바이트 모집 합니다",
# "link": "http://cafe.naver.com/glove/5694353",
# "description": "한달에 10~12일정도 근무 오전근무 아침9시~오후1시까지 (약5~7일근무) 오후근무 오후1시~밤10까지(약1~2일근무) 야간근무 밤10시~ 아침7시까지(3일근무) 입니다 오전 오후 야간 근무가 가능 하셔야 합니다 근무... ",
# "cafename": "[거사모] 거제도 대표 여행,펜션,맛집...",
# "cafeurl": "https://cafe.naver.com/glove"
#
# }
# ]
# }
